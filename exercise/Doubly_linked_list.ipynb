# %%
# In Doubly Linked list there will be pre-reference and next reference and a head

#   ________Node_______
#  | pref | head |nref |
#  |______|______|_____|

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.pref = None
        self.nref = None
        
class Doubly_LL:
    def __init__(self):
        self.head = None
        
    def print_DLL(self):
        if self.head is None:
            print("Doubly Linked List is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->", end = " ")
                n = n.nref
                
    def reverse_print_DLL(self):
        if self.head is None:
            print("Doubly Linked List is empty!")
        else:
            # first we need to to at last node and then start printing in reverse order
            n = self.head
            while n.nref is not None:
                n = n.nref
            # by above code we will be at last node now
            while n is not None:
                print(n.data, "--->", end = " ")
                n = n.pref
                
    def add_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            return
        else:
            print("Doubly Linked List is not empty!")
    
    def add_begin(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.nref = self.head
            self.head.pref = new_node
            self.head = new_node
    
    def add_end(self, data):
        new_node = Node(data)
        if self.head is None :
            self.head = new_node
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            new_node.pref = n
            n.nref = new_node
    
    def add_after(self, data, x):
        
        if self.head is None:
            print("Doubly Linked List is empty so can't add after")
        else:
            # now we need to find the x in Doubly linked list
            n = self.head
            while n is not None:
                if n.data == x:
                    break
                n = n.nref
                
            if n is None:
                print("Given Node is not found in Doubly Linked List")
                
            else:
                new_node = Node(data)
                new_node.nref = n.nref
                new_node.pref = n
                if n.nref is not None: # means we are inserting the next node after rest node
                    # than the last node
                    n.nref.pref = new_node
                n.nref = new_node
                
    def add_before(self, data, x):
        if self.head is None:
            print("DLL is empty!")
        else:
            n = self.head 
            while n is not None:
                if x == n.data:
                    break
                n = n.nref
            if n is None:
                print("Given node is not present in DLL")
            else:
                # we need to be careful whether we are inserting before the first node.
                new_node = Node(data)
                new_node.nref = n
                new_node.pref = n.pref
                if n.pref is not None: # means we are adding rest of the node not at first node
                    n.pref.nref = new_node
                else:
                    self.head = new_node
                n.pref = new_node
        
            
            
    
dl1 = Doubly_LL()
dl1.add_empty(30)
#dl1.add_empty(20)
#l1.add_begin(20)
#l1.add_end(10)
dl1.add_after(50, 30)
dl1.add_before(100, 50)

dl1.print_DLL()
# Out:
# 30 ---> 100 ---> 50 --->

# %%
### Adding deletion operation

class Node:
    def __init__(self, data):
        self.data = data
        self.pref = None
        self.nref = None
        
class Doubly_LL:
    def __init__(self):
        self.head = None
        
    def print_DLL(self):
        if self.head is None:
            print("Doubly Linked List is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->", end = " ")
                n = n.nref
                
    def reverse_print_DLL(self):
        if self.head is None:
            print("Doubly Linked List is empty!")
        else:
            # first we need to to at last node and then start printing in reverse order
            n = self.head
            while n.nref is not None:
                n = n.nref
            # by above code we will be at last node now
            while n is not None:
                print(n.data, "--->", end = " ")
                n = n.pref
                
    def add_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            return
        else:
            print("Doubly Linked List is not empty!")
    
    def add_begin(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.nref = self.head
            self.head.pref = new_node
            self.head = new_node
    
    def add_end(self, data):
        new_node = Node(data)
        if self.head is None :
            self.head = new_node
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            new_node.pref = n
            n.nref = new_node
    
    def add_after(self, data, x):
        
        if self.head is None:
            print("Doubly Linked List is empty so can't add after")
        else:
            # now we need to find the x in Doubly linked list
            n = self.head
            while n is not None:
                if n.data == x:
                    break
                n = n.nref
                
            if n is None:
                print("Given Node is not found in Doubly Linked List")
                
            else:
                new_node = Node(data)
                new_node.nref = n.nref
                new_node.pref = n
                if n.nref is not None: # means we are inserting the next node after rest node
                    # than the last node
                    n.nref.pref = new_node
                n.nref = new_node
                
    def add_before(self, data, x):
        if self.head is None:
            print("DLL is empty!")
        else:
            n = self.head 
            while n is not None:
                if x == n.data:
                    break
                n = n.nref
            if n is None:
                print("Given node is not present in DLL")
            else:
                # we need to be careful whether we are inserting before the first node.
                new_node = Node(data)
                new_node.nref = n
                new_node.pref = n.pref
                if n.pref is not None: # means we are adding rest of the node not at first node
                    n.pref.nref = new_node
                else:
                    self.head = new_node
                n.pref = new_node
                
    def delete_begin(self):
        if self.head is None:
            print("DLL is already empty")
            return
        # when node have single element we need to check this because Doubly Linked list 
        # consist pre reference and next reference
        if self.head.nref is None:
            self.head = None
            print("After deleting this DLL is empty now!")
        else:
            self.head = self.head.nref
            self.head.pref = None
    
    def delete_end(self):
        if self.head is None:
            print("DLL is already empty!")
            return
        if self.head.nref is None:
            self.head = None
            print("After deleting this DLL is empty now")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            n.pref.nref = None
            
    
dl1 = Doubly_LL()
dl1.add_empty(30)
#dl1.add_empty(20)
dl1.add_begin(20)
#dl1.add_end(10)
#dl1.add_after(50, 30)
#dl1.add_before(100, 50)
# dl1.delete_begin()
dl1.delete_end()

dl1.print_DLL()
# Out:
# 20 --->

# %%
### Adding delete by value

### Adding deletion operation

class Node:
    def __init__(self, data):
        self.data = data
        self.pref = None
        self.nref = None
        
class Doubly_LL:
    def __init__(self):
        self.head = None
        
    def print_DLL(self):
        if self.head is None:
            print("Doubly Linked List is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->", end = " ")
                n = n.nref
                
    def reverse_print_DLL(self):
        if self.head is None:
            print("Doubly Linked List is empty!")
        else:
            # first we need to to at last node and then start printing in reverse order
            n = self.head
            while n.nref is not None:
                n = n.nref
            # by above code we will be at last node now
            while n is not None:
                print(n.data, "--->", end = " ")
                n = n.pref
                
    def add_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            return
        else:
            print("Doubly Linked List is not empty!")
    
    def add_begin(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.nref = self.head
            self.head.pref = new_node
            self.head = new_node
    
    def add_end(self, data):
        new_node = Node(data)
        if self.head is None :
            self.head = new_node
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            new_node.pref = n
            n.nref = new_node
    
    def add_after(self, data, x):
        
        if self.head is None:
            print("Doubly Linked List is empty so can't add after")
        else:
            # now we need to find the x in Doubly linked list
            n = self.head
            while n is not None:
                if n.data == x:
                    break
                n = n.nref
                
            if n is None:
                print("Given Node is not found in Doubly Linked List")
                
            else:
                new_node = Node(data)
                new_node.nref = n.nref
                new_node.pref = n
                if n.nref is not None: # means we are inserting the next node after rest node
                    # than the last node
                    n.nref.pref = new_node
                n.nref = new_node
                
    def add_before(self, data, x):
        if self.head is None:
            print("DLL is empty!")
        else:
            n = self.head 
            while n is not None:
                if x == n.data:
                    break
                n = n.nref
            if n is None:
                print("Given node is not present in DLL")
            else:
                # we need to be careful whether we are inserting before the first node.
                new_node = Node(data)
                new_node.nref = n
                new_node.pref = n.pref
                if n.pref is not None: # means we are adding rest of the node not at first node
                    n.pref.nref = new_node
                else:
                    self.head = new_node
                n.pref = new_node
                
    def delete_begin(self):
        if self.head is None:
            print("DLL is already empty")
            return
        # when node have single element we need to check this because Doubly Linked list 
        # consist pre reference and next reference
        if self.head.nref is None:
            self.head = None
            print("After deleting this DLL is empty now!")
        else:
            self.head = self.head.nref
            self.head.pref = None
    
    def delete_end(self):
        if self.head is None:
            print("DLL is already empty!")
            return
        if self.head.nref is None:
            self.head = None
            print("After deleting this DLL is empty now")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            n.pref.nref = None
            
    def delete_by_value(self, x):
        if self.head is None:
            print("DLL is already empty!")
            return
        if self.head.nref is None: # may be that single node is x
            if self.head.data == x:
                self.head = None
                
            else:
                print("Given Node is not present Doubly Linked List")
            return
        # when this is first node
        if self.head.data == x:
            self.head = self.head.nref
            self.head.pref = None
            return
        
        n = self.head
        while n.nref is not None: # by this it will not check last node data because when n.ref
            #will be None then while loop will not execute 
            if x == n.data:
                break
            n = n.nref
            
        if n.nref is None:
            # we can check whether n.data last node is the x
            if n.data == x:
                n.pref.nref = None
            else:
                print("Given node is not present in DLL!")
        else:
            n.nref.pref = n.nref
            n.pref.nref = n.nref
            
            
#         if n.nref is not None: # means when break statement execute
#             n.nref.pref = n.pref
#             n.pref.nref = n.nref
#         else: # means n.nref is None we can check may be n.data last node is the x
#             if n.data == x:
#                 n.pref.nref = None
#             else:
#                 print("Given node is not present in the DLL!")
                
            
            
        
    
        
                
        
            
    
dl1 = Doubly_LL()
dl1.add_empty(30)
#dl1.add_empty(20)
#dl1.add_begin(20)
#dl1.add_end(10)
#dl1.add_after(50, 30)
#dl1.add_before(100, 50)
# dl1.delete_begin()
#dl1.delete_end()
dl1.delete_by_value(30)

dl1.print_DLL()
# Out:
# Doubly Linked List is empty!
