# %% [markdown]
# #### LinkedList
# #### 1. Singly LinkedList

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.ref = None   # link
    
node1 = Node(10)
print(node1)

# %% [markdown]
# means it gives the reference of the newly created object.

# %%
print(node1.ref)
# Out:
# None

# %%
class Node:
    def __init__(self, data):           # this creates indivisual node, so to connect it we need 
        self.data = data                # Another class 
        self.ref = None   # link
    
class LinkedList:
    def __init__(self):
        self.head = None     # means empty list or eampty head empty linkedlist.
        
    def print_LL(self):  #  this method is traversal method for LinkedList
        if self.head is None:
            print("LL is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data)
                n = n.ref
                
LL1 = LinkedList()
LL1.print_LL()
# Out:
# LL is empty!

# %%
# added method adding element at beginning of the list
class Node:
    def __init__(self, data):           # this creates indivisual node, so to connect it we need 
        self.data = data                # Another class 
        self.ref = None   # link
    
class LinkedList:
    def __init__(self):
        self.head = None     # means empty list or eampty head empty linkedlist.
        
    def print_LL(self):  #  this method is traversal method for LinkedList
        if self.head is None:
            print("LL is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data)
                n = n.ref
                
    def add_begin(self, data):
        new_node = Node(data)      # by this we make new node 
        new_node.ref = self.head   # now the previous head should be new_node reference
        self.head = new_node       # new head will be new_node head Object 
        
        
                
LL1 = LinkedList()
LL1.add_begin(10)
LL1.add_begin(20)

LL1.print_LL()
# Out:
# 20
# 10

# %%
# Will add another adding method that is adding element at the end of the linkedlist.
class Node:
    def __init__(self, data):           # this creates indivisual node, so to connect it we need 
        self.data = data                # Another class 
        self.ref = None   # link
    
class LinkedList:
    def __init__(self):
        self.head = None     # means empty list or eampty head empty linkedlist.
        
    def print_LL(self):  #  this method is traversal method for LinkedList
        if self.head is None:
            print("LL is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->",end = " " ) # we can add arrow representation to look better
                n = n.ref
                
    def add_begin(self, data):
        new_node = Node(data)      # by this we make new node 
        new_node.ref = self.head   # now the previous head should be new_node reference
        self.head = new_node       # new head will be new_node head Object 
        
    def add_end(self, data):
        
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node    # out of while loop means we traverse at the last element and 
            # at this time n.ref have null as reference so we need to change it new_node that
            # have head and n.ref as null menas now that will be last node and thus we will add 
            # data at the end 
            
        
        
                
LL1 = LinkedList()
# LL1.add_begin(10)
LL1.add_end(100)
# LL1.add_end(500)

# LL1.add_begin(20)

LL1.print_LL()
# Out:
# 100 --->

# %%
# Will add another adding method that is adding element in between of the linkedlist.
class Node:
    def __init__(self, data):           # this creates indivisual node, so to connect it we need 
        self.data = data                # Another class 
        self.ref = None   # link
    
class LinkedList:
    def __init__(self):
        self.head = None     # means empty list or eampty head empty linkedlist.
        
    def print_LL(self):  #  this method is traversal method for LinkedList
        if self.head is None:
            print("LL is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->",end = " " ) # we can add arrow representation to look better
                n = n.ref
                
    def add_begin(self, data):
        new_node = Node(data)      # by this we make new node 
        new_node.ref = self.head   # now the previous head should be new_node reference
        self.head = new_node       # new head will be new_node head Object 
        
    def add_end(self, data):
        
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node    # out of while loop means we traverse at the last element and 
            # at this time n.ref have null as reference so we need to change it new_node that
            # have head and n.ref as null menas now that will be last node and thus we will add 
            # data at the end 
    def add_after(self, data, x):
        
        n = self.head  # for the traversal we took this
        while n is not None:
            if x == n.data:
                break  # if it is true means we got the position after which we need to insert 
                       # new data.
            n = n.ref  # above we have taken break statement so no need to else part if you want 
                       # you can write this in else part
                
        # while loop will be turminate on two condition 1 when we found x = n.data, 2.if n is None
        if n is None:
            print("Node is not present in LL!")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
            

                
LL1 = LinkedList()
# LL1.add_begin(10)
#LL1.add_end(100)
# LL1.add_end(500)
LL1.add_after(200, 100)

# LL1.add_begin(20)

LL1.print_LL()
# Out:
# Node is not present in LL!
# LL is empty!

# %%
#### Add before node method will be added
class Node:
    def __init__(self, data):           # this creates indivisual node, so to connect it we need 
        self.data = data                # Another class 
        self.ref = None   # link
    
class LinkedList:
    def __init__(self):
        self.head = None     # means empty list or eampty head empty linkedlist.
        
    def print_LL(self):  #  this method is traversal method for LinkedList
        if self.head is None:
            print("LL is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->",end = " " ) # we can add arrow representation to look better
                n = n.ref
                
    def add_begin(self, data):
        new_node = Node(data)      # by this we make new node 
        new_node.ref = self.head   # now the previous head should be new_node reference
        self.head = new_node       # new head will be new_node head Object 
        
    def add_end(self, data):
        
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node    # out of while loop means we traverse at the last element and 
            # at this time n.ref have null as reference so we need to change it new_node that
            # have head and n.ref as null menas now that will be last node and thus we will add 
            # data at the end 
    def add_after(self, data, x):
        
        n = self.head  # for the traversal we took this
        while n is not None:
            if x == n.data:
                break  # if it is true means we got the position after which we need to insert 
                       # new data.
            n = n.ref  # above we have taken break statement so no need to else part if you want 
                       # you can write this in else part
                
        # while loop will be turminate on two condition 1 when we found x = n.data, 2.if n is None
        if n is None:
            print("Node is not present in LL!")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
    def add_before(self, data, x):
        if self.head is None:
            print("Linkedlist is empty!")
            return  # if it is empty then it will print message and wont execute anything
              
        if self.head.data == x: # when we access this we need check whether it is empty or not
            #   if self.head is empty then self.head.data will give error so we need to check it
            new_node = Node(data)      # by this we make new node 
            new_node.ref = self.head   # now the previous head should be new_node reference
            self.head = new_node       # new head will be new_node head Object 
            return 
        
        n = self.head
        while n.ref is not None:
            if n.ref.data == x:
                break
            n = n.ref
            
        # here the control will come out of this due to two reason and these are
        if n.ref is None:
            print("LinkedList is not found!")
            
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node

            
            

                
LL1 = LinkedList()
LL1.add_begin(10)
LL1.add_before(20, 10)
LL1.add_before(30, 100)
#LL1.add_end(100)
# LL1.add_end(500)
#LL1.add_after(200, 100)

# LL1.add_begin(20)

LL1.print_LL()
# Out:
# LinkedList is not found!
# 20 ---> 10 --->

# %%
#### Add element when LinkedList is empty for this
#### first we need to check whether LinkedList is empty or not 
class Node:
    def __init__(self, data):           # this creates indivisual node, so to connect it we need 
        self.data = data                # Another class 
        self.ref = None   # link
    
class LinkedList:
    def __init__(self):
        self.head = None     # means empty list or eampty head empty linkedlist.
        
    def print_LL(self):  #  this method is traversal method for LinkedList
        if self.head is None:
            print("LL is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->",end = " " ) # we can add arrow representation to look better
                n = n.ref
                
    def add_begin(self, data):
        new_node = Node(data)      # by this we make new node 
        new_node.ref = self.head   # now the previous head should be new_node reference
        self.head = new_node       # new head will be new_node head Object 
        
    def add_end(self, data):
        
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node    # out of while loop means we traverse at the last element and 
            # at this time n.ref have null as reference so we need to change it new_node that
            # have head and n.ref as null menas now that will be last node and thus we will add 
            # data at the end 
    def add_after(self, data, x):
        
        n = self.head  # for the traversal we took this
        while n is not None:
            if x == n.data:
                break  # if it is true means we got the position after which we need to insert 
                       # new data.
            n = n.ref  # above we have taken break statement so no need to else part if you want 
                       # you can write this in else part
                
        # while loop will be turminate on two condition 1 when we found x = n.data, 2.if n is None
        if n is None:
            print("Node is not present in LL!")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
    def add_before(self, data, x):
        if self.head is None:
            print("Linkedlist is empty!")
            return  # if it is empty then it will print message and wont execute anything
              
        if self.head.data == x: # when we access this we need check whether it is empty or not
            #   if self.head is empty then self.head.data will give error so we need to check it
            new_node = Node(data)      # by this we make new node 
            new_node.ref = self.head   # now the previous head should be new_node reference
            self.head = new_node       # new head will be new_node head Object 
            return 
        
        n = self.head
        while n.ref is not None:
            if n.ref.data == x:
                break
            n = n.ref
            
        # here the control will come out of this due to two reason and these are
        if n.ref is None:
            print("LinkedList is not found!")
            
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("LinkedList  is not empty!")

            
            

                
LL1 = LinkedList()
#LL1.add_begin(10)
# LL1.add_before(20, 10)
# LL1.add_before(30, 100)
#LL1.add_end(100)
# LL1.add_end(500)
#LL1.add_after(200, 100)

# LL1.add_begin(20)
LL1.insert_empty(70)
LL1.print_LL()
# Out:
# 70 --->

# %%
### deletion of element from beginning of the LinkedList
# for this first we need to check wether it is empty or not , if it is empty then we can't 
# delete element from this so we just print message for that and if not empty then write the
# operation for that.

class Node:
    def __init__(self, data):           # this creates indivisual node, so to connect it we need 
        self.data = data                # Another class 
        self.ref = None   # link
    
class LinkedList:
    def __init__(self):
        self.head = None     # means empty list or eampty head empty linkedlist.
        
    def print_LL(self):  #  this method is traversal method for LinkedList
        if self.head is None:
            print("LL is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->",end = " " ) # we can add arrow representation to look better
                n = n.ref
                
    def add_begin(self, data):
        new_node = Node(data)      # by this we make new node 
        new_node.ref = self.head   # now the previous head should be new_node reference
        self.head = new_node       # new head will be new_node head Object 
        
    def add_end(self, data):
        
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node    # out of while loop means we traverse at the last element and 
            # at this time n.ref have null as reference so we need to change it new_node that
            # have head and n.ref as null menas now that will be last node and thus we will add 
            # data at the end 
    def add_after(self, data, x):
        
        n = self.head  # for the traversal we took this
        while n is not None:
            if x == n.data:
                break  # if it is true means we got the position after which we need to insert 
                       # new data.
            n = n.ref  # above we have taken break statement so no need to else part if you want 
                       # you can write this in else part
                
        # while loop will be turminate on two condition 1 when we found x = n.data, 2.if n is None
        if n is None:
            print("Node is not present in LL!")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
    def add_before(self, data, x):
        if self.head is None:
            print("Linkedlist is empty!")
            return  # if it is empty then it will print message and wont execute anything
              
        if self.head.data == x: # when we access this we need check whether it is empty or not
            #   if self.head is empty then self.head.data will give error so we need to check it
            new_node = Node(data)      # by this we make new node 
            new_node.ref = self.head   # now the previous head should be new_node reference
            self.head = new_node       # new head will be new_node head Object 
            return 
        
        n = self.head
        while n.ref is not None:
            if n.ref.data == x:
                break
            n = n.ref
            
        # here the control will come out of this due to two reason and these are
        if n.ref is None:
            print("LinkedList is not found!")
            
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("LinkedList  is not empty!")
            
    def delete_begin(self):
        if self.head is None:
            print("LinkedList is empty so we can't delete nodes")
            
        else:
            self.head = self.head.ref
    

            
            

                
LL1 = LinkedList()
LL1.add_begin(10)
LL1.add_before(20, 10)
# LL1.add_before(30, 100)
#LL1.add_end(100)
# LL1.add_end(500)
#LL1.add_after(200, 100)

# LL1.add_begin(20)
LL1.delete_begin()
LL1.print_LL()
# Out:
# 10 --->

# %%
# to delete the element from the last of the LinkedList fir we need to check whether LinkedList
# is empty or not if it is empty then just write a message for that, and if not empty then first
# we need to traverse to the 2nd last element of the LL and for this we need some condition and
# after reaching there we need to change node ref as null that will be now last element.


class Node:
    def __init__(self, data):           # this creates indivisual node, so to connect it we need 
        self.data = data                # Another class 
        self.ref = None   # link
    
class LinkedList:
    def __init__(self):
        self.head = None     # means empty list or eampty head empty linkedlist.
        
    def print_LL(self):  #  this method is traversal method for LinkedList
        if self.head is None:
            print("LL is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->",end = " " ) # we can add arrow representation to look better
                n = n.ref
                
    def add_begin(self, data):
        new_node = Node(data)      # by this we make new node 
        new_node.ref = self.head   # now the previous head should be new_node reference
        self.head = new_node       # new head will be new_node head Object 
        
    def add_end(self, data):
        
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node    # out of while loop means we traverse at the last element and 
            # at this time n.ref have null as reference so we need to change it new_node that
            # have head and n.ref as null menas now that will be last node and thus we will add 
            # data at the end 
    def add_after(self, data, x):
        
        n = self.head  # for the traversal we took this
        while n is not None:
            if x == n.data:
                break  # if it is true means we got the position after which we need to insert 
                       # new data.
            n = n.ref  # above we have taken break statement so no need to else part if you want 
                       # you can write this in else part
                
        # while loop will be turminate on two condition 1 when we found x = n.data, 2.if n is None
        if n is None:
            print("Node is not present in LL!")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
    def add_before(self, data, x):
        if self.head is None:
            print("Linkedlist is empty!")
            return  # if it is empty then it will print message and wont execute anything
              
        if self.head.data == x: # when we access this we need check whether it is empty or not
            #   if self.head is empty then self.head.data will give error so we need to check it
            new_node = Node(data)      # by this we make new node 
            new_node.ref = self.head   # now the previous head should be new_node reference
            self.head = new_node       # new head will be new_node head Object 
            return 
        
        n = self.head
        while n.ref is not None:
            if n.ref.data == x:
                break
            n = n.ref
            
        # here the control will come out of this due to two reason and these are
        if n.ref is None:
            print("LinkedList is not found!")
            
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("LinkedList  is not empty!")
            
    def delete_begin(self):
        if self.head is None:
            print("LinkedList is empty so we can't delete nodes")
            
        else:
            self.head = self.head.ref
            
    def delete_end(self):
        if self.head is None:
            print("LinkedList is empty so we can't delete nodes")
            
        else:
            n = self.head
            while n.ref.ref is not None:
                n = n.ref
                
            n.ref = None
            
            
        
            
            
        
        
    

            
            

                
LL1 = LinkedList()
LL1.add_begin(10)
# LL1.add_before(20, 10)

#LL1.add_end(100)
# LL1.add_end(500)
#LL1.add_after(200, 100)

# LL1.add_begin(20)
# LL1.delete_begin()
LL1.delete_end()
LL1.print_LL()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [31], in <cell line: 136>()
#     127 LL1.add_begin(10)
#     128 # LL1.add_before(20, 10)
#     129
#     130 #LL1.add_end(100)
#    (...)
#     134 # LL1.add_begin(20)
#     135 # LL1.delete_begin()
# --> 136 LL1.delete_end()
#     137 LL1.print_LL()
#
# Input In [31], in LinkedList.delete_end(self)
#     107 else:
#     108     n = self.head
# --> 109     while n.ref.ref is not None:
#     110         n = n.ref
#     112     n.ref = None
#
# AttributeError: 'NoneType' object has no attribute 'ref'

# %%
#when we have only one reference and when we delete that then n.ref referes None which
# will give error when we check condition n.ref.ref so to avoid this we need to write another 
# condition as well
class Node:
    def __init__(self, data):           # this creates indivisual node, so to connect it we need 
        self.data = data                # Another class 
        self.ref = None   # link
    
class LinkedList:
    def __init__(self):
        self.head = None     # means empty list or eampty head empty linkedlist.
        
    def print_LL(self):  #  this method is traversal method for LinkedList
        if self.head is None:
            print("LL is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->",end = " " ) # we can add arrow representation to look better
                n = n.ref
                
    def add_begin(self, data):
        new_node = Node(data)      # by this we make new node 
        new_node.ref = self.head   # now the previous head should be new_node reference
        self.head = new_node       # new head will be new_node head Object 
        
    def add_end(self, data):
        
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node    # out of while loop means we traverse at the last element and 
            # at this time n.ref have null as reference so we need to change it new_node that
            # have head and n.ref as null menas now that will be last node and thus we will add 
            # data at the end 
    def add_after(self, data, x):
        
        n = self.head  # for the traversal we took this
        while n is not None:
            if x == n.data:
                break  # if it is true means we got the position after which we need to insert 
                       # new data.
            n = n.ref  # above we have taken break statement so no need to else part if you want 
                       # you can write this in else part
                
        # while loop will be turminate on two condition 1 when we found x = n.data, 2.if n is None
        if n is None:
            print("Node is not present in LL!")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
    def add_before(self, data, x):
        if self.head is None:
            print("Linkedlist is empty!")
            return  # if it is empty then it will print message and wont execute anything
              
        if self.head.data == x: # when we access this we need check whether it is empty or not
            #   if self.head is empty then self.head.data will give error so we need to check it
            new_node = Node(data)      # by this we make new node 
            new_node.ref = self.head   # now the previous head should be new_node reference
            self.head = new_node       # new head will be new_node head Object 
            return 
        
        n = self.head
        while n.ref is not None:
            if n.ref.data == x:
                break
            n = n.ref
            
        # here the control will come out of this due to two reason and these are
        if n.ref is None:
            print("LinkedList is not found!")
            
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("LinkedList  is not empty!")
            
    def delete_begin(self):
        if self.head is None:
            print("LinkedList is empty so we can't delete nodes")
            
        else:
            self.head = self.head.ref
            
    def delete_end(self):
        if self.head is None:
            print("LinkedList is empty so we can't delete nodes")
        elif self.head.ref is None:
            self.head = None
        else:
            n = self.head
            while n.ref.ref is not None:
                n = n.ref
                
            n.ref = None
            
            
        
            
            
        
        
    

            
            

                
LL1 = LinkedList()
LL1.add_begin(10)
# LL1.add_before(20, 10)

#LL1.add_end(100)
# LL1.add_end(500)
#LL1.add_after(200, 100)

# LL1.add_begin(20)
# LL1.delete_begin()
LL1.delete_end()
LL1.print_LL()
# Out:
# LL is empty!

# %%
# here we will define deletion method in which user will define whether he want delete from 
# beginning, end , or from any position from of the Linked List.

class Node:
    def __init__(self, data):           # this creates indivisual node, so to connect it we need 
        self.data = data                # Another class 
        self.ref = None   # link
    
class LinkedList:
    def __init__(self):
        self.head = None     # means empty list or eampty head empty linkedlist.
        
    def print_LL(self):  #  this method is traversal method for LinkedList
        if self.head is None:
            print("LL is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->",end = " " ) # we can add arrow representation to look better
                n = n.ref
                
    def add_begin(self, data):
        new_node = Node(data)      # by this we make new node 
        new_node.ref = self.head   # now the previous head should be new_node reference
        self.head = new_node       # new head will be new_node head Object 
        
    def add_end(self, data):
        
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node    # out of while loop means we traverse at the last element and 
            # at this time n.ref have null as reference so we need to change it new_node that
            # have head and n.ref as null menas now that will be last node and thus we will add 
            # data at the end 
    def add_after(self, data, x):
        
        n = self.head  # for the traversal we took this
        while n is not None:
            if x == n.data:
                break  # if it is true means we got the position after which we need to insert 
                       # new data.
            n = n.ref  # above we have taken break statement so no need to else part if you want 
                       # you can write this in else part
                
        # while loop will be turminate on two condition 1 when we found x = n.data, 2.if n is None
        if n is None:
            print("Node is not present in LL!")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
    def add_before(self, data, x):
        if self.head is None:
            print("Linkedlist is empty!")
            return  # if it is empty then it will print message and wont execute anything
                    # control will come out of the method add_before.
              
        if self.head.data == x: # condition whether x is first node.
            
            new_node = Node(data)      # by this we make new node 
            new_node.ref = self.head   # now the previous head should be new_node reference
            self.head = new_node       # new head will be new_node head Object 
            return 
        
        n = self.head
        while n.ref is not None:
            if n.ref.data == x:
                break
            n = n.ref
            
        # here the control will come out of this due to two reason and these are
        if n.ref is None:   # reason first 
            print("LinkedList is not found!")
            
        else:  # reason second means we found the x by n.ref.data = x
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("LinkedList  is not empty!")
            
    def delete_begin(self):
        if self.head is None:
            print("LinkedList is empty so we can't delete nodes")
            
        else:
            self.head = self.head.ref
            
    def delete_end(self):
        if self.head is None:
            print("LinkedList is empty so we can't delete nodes")
        elif self.head.ref is None:
            self.head = None
        else:
            n = self.head
            while n.ref.ref is not None:
                n = n.ref
                
            n.ref = None
            
    def delete_by_value(self, x): # here x is user value 
        # we keep it mind that the x must be in data other wise we wont be able to delete
        
        if self.head is None:
            print("Can't delete LL is empty!")
            return   # here if this condition will satisfied then after printing the message
                     # control will come out from the method delete_by_value 
        if x == self.head.data: # this is the condition whether first element is x
            self.head = self.head.ref
            return
        
        n = self.head
        while n.ref is not None:
            if x == n.ref.data:
                break
            n = n.ref
            
        #### control can come out due to two condition which are as 
        if n.ref is None:
            print("Node is not present!")
        else:
            n.ref = n.ref.ref
                
LL1 = LinkedList()
# LL1.add_begin(10)
# LL1.add_begin(30)
# LL1.add_begin(20)
LL1.delete_by_value(30)
LL1.print_LL()
# Out:
# Can't delete LL is empty!
# LL is empty!

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.ref = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    #----- print LinkedList ----------
    
    def print_LL(self):
        if self.head is None:
            print("LikedList is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->", end = " ")
                n = n.ref
                
    #------ Adding data at beginning-----
    def add_begin(self, data):
        new_node = Node(data)
        new_node.ref = self.head
        self.head = new_node
        
    #-------adding data at the end ------
    def add_end(self, data):
        new_node = Node(data)
        if self.head is None:  # means we are at end node
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
            # when n.ref will be null then control will come out of while loop    
            n.ref = new_node
    def add_after(self, data, x):
        n = self.head   # for traverse
        while n is not None:
            if x == n.data:
                break
            n = n.ref
        # if control is here means either while loop break with condition satisfied or n.ref None
        if n is None: #means we traverse through the all node but x data didn't match
            print("Node is not present!")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
    def add_before(self, data, x):
        if self.head is None:
            print("LinkedList is empty!")
            return 
        # this condition is whether first node is the correct position for x
        if self.head.data == x:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
            return
        
        n = self.head
        while n.ref is not None:
            if n.ref.data == x:
                break
            n = n.ref
            
        if n.ref is None:
            print("LinkedList is not Found!")
            
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
    def insert_empty(self):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("LinkedList is not empty")
        
    def delete_begin(self):
        if self.head is None:
            print("LinkedList is empty so we can't delete node")
            
        else:
            self.head = slef.head.ref
    def delete_end(self):
        if self.head is None:
            print("LinkedList is empty so we can't delete")
            
        elif self.head.ref is None: # if we have only one node
            self.head = None
            
        else:
            n = self.head
            while n.ref.ref is None:
                # check until last node is None
                n = n.ref
                
            n.ref = None
            
    def delete_by_value(self, x):
        
        if self.head is None:
            print("Can't delete LL is empty!")
            return
        if x == self.head.data :
            self.head = self.head.ref
            return
        n = self.head
        while n.ref is not None:
            if x == n.ref.data:
                break
            n = n.ref
            
        if n.ref is None:
            print("Node is not present!")
            
        else:
            n.ref = n.ref.ref
            
            
            
LL1 = LinkedList()
LL1.add_begin(12)
LL1.add_begin(20)
LL1.add_begin(15)


LL1.delete_by_value(12)
LL1.print_LL()
# Out:
# 15 ---> 20 --->
