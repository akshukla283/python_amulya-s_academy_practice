# %% [markdown]
# #### Inserting/Adding Element to the empty Linked List.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.ref = None

class LinkedList:
    def __init__(self):
        self.head = None  # means we have no node empty LinkedList
        
    def print_LL(self):     # Traversal operations
        if self.head is None:
            print("LinkedList is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data,"--->", end = " ")
                n = n.ref
                
    def add_begin(self,data):
        new_node = Node(data)
        new_node.ref = self.head
        self.head = new_node
        
    def add_end(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node
            
    def add_after(self, data, x): # no ned to check that maybe it will be first node because we
        # will ad element at after that node
        n = self.head
        while n is not None:
            if x == n.data:
                break
            n = n.ref
        if n is None:
            print("node is not present in LL")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
    def add_before(self, data, x):# we need to check whether linkedlist is empty, because
        # empty linked will give error so avoidthis we will use condition 
        if self.head is None:
            print("LinkedList is empty!")
            return
        
        if self.head.data == x:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
            return
        
        n = self.head
        while n.ref is not None:
            if n.ref.data == x:
                break
            n = n.ref
        if n.ref is None:
            print("Node is not found!")
        else:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
            
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("LinkedList is not empty!")
        
        
            
            
            
LL1 = LinkedList()
LL1.add_before(10, 20)
# LL1.add_end(10)
# LL1.add_end(30)

# LL1.insert_empty(10)
LL1.print_LL()
# Out:
# LinkedList is empty!
# LinkedList is empty!

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.ref = None

class LinkedList:
    def __init__(self):
        self.head = None  # means we have no node empty LinkedList
        
    def print_LL(self):     # Traversal operations
        if self.head is None:
            print("LinkedList is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data,"--->", end = " ")
                n = n.ref
                
    def add_begin(self,data):
        new_node = Node(data)
        new_node.ref = self.head
        self.head = new_node
        
    def add_end(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node
    def add_after(self, data, x):
        n = self.head
        while n is not None:
            if x == n.data:
                break
            n = n.ref
        if n is None:
            print("node is not present in LL")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
    def add_before(self, data, x):
        # we need to check whether linkedlist is empty, because empty linked
        # will give error so to avoid this we will use condition 
        
        if self.head is None:
            print("LinkedList is empty!")
            return
        
        if self.head.data == x:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
            return
        n = self.head
        while n.ref is not None:
            if n.ref.data == x:
                break
            n = n.ref
        if n.ref is None:
            print("Node is not found!")
        else:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("LinkedList is not empty!")
        
        
            
            
            
LL1 = LinkedList()
LL1.insert_empty(10)
LL1.insert_empty(20) # again insert while one element already been added
LL1.print_LL()
# Out:
# LinkedList is not empty!
# 10 --->

# %% [markdown]
# #### Delete the first node in Linked list| Delete at the beginning

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.ref = None

class LinkedList:
    def __init__(self):
        self.head = None  # means we have no node empty LinkedList
        
    def print_LL(self):     # Traversal operations
        if self.head is None:
            print("LinkedList is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data,"--->", end = " ")
                n = n.ref
                
    def add_begin(self,data):
        new_node = Node(data)
        new_node.ref = self.head
        self.head = new_node
        
    def add_end(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node
    def add_after(self, data, x):
        n = self.head
        while n is not None:
            if x == n.data:
                break
            n = n.ref
        if n is None:
            print("node is not present in LL")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
    def add_before(self, data, x):# we need to check whether linkedlist is empty, because empty linked
                                   # will give error so avoidthis we will use condition 
        if self.head is None:
            print("LinkedList is empty!")
            return
        
        if self.head.data == x:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
            return
        n = self.head
        while n.ref is not None:
            if n.ref.data == x:
                break
            n = n.ref
        if n.ref is None:
            print("Node is not found!")
        else:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
            
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("LinkedList is not empty!")
            
    def delete_begin(self):
        if self.head is None:
            print("LinkedList is empty so we can't delete nodes!")
            
        else:
            self.head = self.head.ref
        
        
          
LL1 = LinkedList()
LL1.add_begin(10) # let's first add some element
LL1.add_begin(20)
LL1.add_begin(30) 

LL1.print_LL()
# Out:
# 30 ---> 20 ---> 10 --->

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.ref = None

class LinkedList:
    def __init__(self):
        self.head = None  # means we have no node empty LinkedList
        
    def print_LL(self):     # Traversal operations
        if self.head is None:
            print("LinkedList is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data,"--->", end = " ")
                n = n.ref
                
    def add_begin(self,data):
        new_node = Node(data)
        new_node.ref = self.head
        self.head = new_node
        
    def add_end(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node
    def add_after(self, data, x):
        n = self.head
        while n is not None:
            if x == n.data:
                break
            n = n.ref
        if n is None:
            print("node is not present in LL")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
    def add_before(self, data, x):# we need to check whether linkedlist is empty, because empty linked
                                   # will give error so avoidthis we will use condition 
        if self.head is None:
            print("LinkedList is empty!")
            return
        
        if self.head.data == x:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
            return
        n = self.head
        while n.ref is not None:
            if n.ref.data == x:
                break
            n = n.ref
        if n.ref is None:
            print("Node is not found!")
        else:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
            
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("LinkedList is not empty!")
            
    def delete_begin(self):
        if self.head is None:
            print("LinkedList is empty so we can't delete nodes!")
            
        else:
            self.head = self.head.ref
        
        
          
LL1 = LinkedList()
LL1.add_begin(10)
LL1.add_begin(20)
LL1.add_begin(30)
LL1.delete_begin()

LL1.print_LL()
# Out:
# 20 ---> 10 --->

# %% [markdown]
# As here we can see that 30 is deleted now

# %%
### check when LinkedList already empty and we just want to deleted
class Node:
    def __init__(self, data):
        self.data = data
        self.ref = None

class LinkedList:
    def __init__(self):
        self.head = None  # means we have no node empty LinkedList
        
    def print_LL(self):     # Traversal operations
        if self.head is None:
            print("LinkedList is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data,"--->", end = " ")
                n = n.ref
                
    def add_begin(self,data):
        new_node = Node(data)
        new_node.ref = self.head
        self.head = new_node
        
    def add_end(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node
    def add_after(self, data, x):
        n = self.head
        while n is not None:
            if x == n.data:
                break
            n = n.ref
        if n is None:
            print("node is not present in LL")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
    def add_before(self, data, x):# we need to check whether linkedlist is empty, because empty linked
                                   # will give error so avoidthis we will use condition 
        if self.head is None:
            print("LinkedList is empty!")
            return
        
        if self.head.data == x:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
            return
        n = self.head
        while n.ref is not None:
            if n.ref.data == x:
                break
            n = n.ref
        if n.ref is None:
            print("Node is not found!")
        else:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
            
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("LinkedList is not empty!")
            
    def delete_begin(self):
        if self.head is None:
            print("LinkedList is empty so we can't delete nodes!")
            
        else:
            self.head = self.head.ref
        
        
          
LL1 = LinkedList()
LL1.delete_begin()

LL1.print_LL()
# Out:
# LinkedList is empty so we can't delete nodes!
# LinkedList is empty!

# %% [markdown]
# ### Delete the last node in Linked list| Delete at the End.

# %%
### check when LinkedList already empty and we just want to deleted
class Node:
    def __init__(self, data):
        self.data = data
        self.ref = None

class LinkedList:
    def __init__(self):
        self.head = None  # means we have no node empty LinkedList
        
    def print_LL(self):     # Traversal operations
        if self.head is None:
            print("LinkedList is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data,"--->", end = " ")
                n = n.ref
                
    def add_begin(self,data):
        new_node = Node(data)
        new_node.ref = self.head
        self.head = new_node
        
    def add_end(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node
    def add_after(self, data, x):
        n = self.head
        while n is not None:
            if x == n.data:
                break
            n = n.ref
        if n is None:
            print("node is not present in LL")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
    def add_before(self, data, x):# we need to check whether linkedlist is empty, because empty linked
                                   # will give error so avoidthis we will use condition 
        if self.head is None:
            print("LinkedList is empty!")
            return
        
        if self.head.data == x:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
            return
        n = self.head
        while n.ref is not None:
            if n.ref.data == x:
                break
            n = n.ref
        if n.ref is None:
            print("Node is not found!")
        else:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
            
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("LinkedList is not empty!")
            
    def delete_begin(self):
        if self.head is None:
            print("LinkedList is empty so we can't delete nodes!")
            
        else:
            self.head = self.head.ref
    
    def delete_end(self):
        if self.head is None:
            print("LL is empty so we can't delete nodes!")
        else:
            n = self.head
            while n.ref.ref is not None:
                n = n.ref
            n.ref = None
            
            
            

LL1 = LinkedList()
LL1.add_begin(10)
LL1.add_begin(20)
LL1.add_begin(30)
LL1.delete_end()
LL1.print_LL()
# Out:
# 30 ---> 20 --->

# %%
# when linkedlist contain only one node then after deleting end node we we get error because reference 
# will point to none

### check when LinkedList already empty and we just want to deleted
class Node:
    def __init__(self, data):
        self.data = data
        self.ref = None

class LinkedList:
    def __init__(self):
        self.head = None  # means we have no node empty LinkedList
        
    def print_LL(self):     # Traversal operations
        if self.head is None:
            print("LinkedList is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data,"--->", end = " ")
                n = n.ref
                
    def add_begin(self,data):
        new_node = Node(data)
        new_node.ref = self.head
        self.head = new_node
        
    def add_end(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node
    def add_after(self, data, x):
        n = self.head
        while n is not None:
            if x == n.data:
                break
            n = n.ref
        if n is None:
            print("node is not present in LL")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
    def add_before(self, data, x):# we need to check whether linkedlist is empty, because empty linked
                                   # will give error so avoidthis we will use condition 
        if self.head is None:
            print("LinkedList is empty!")
            return
        
        if self.head.data == x:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
            return
        n = self.head
        while n.ref is not None:
            if n.ref.data == x:
                break
            n = n.ref
        if n.ref is None:
            print("Node is not found!")
        else:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
            
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("LinkedList is not empty!")
            
    def delete_begin(self):
        if self.head is None:
            print("LinkedList is empty so we can't delete nodes!")
            
        else:
            self.head = self.head.ref
    
    def delete_end(self):
        if self.head is None:
            print("LL is empty so we can't delete nodes!")
        else:
            n = self.head
            while n.ref.ref is not None:
                n = n.ref
            n.ref = None
            
            
            

LL1 = LinkedList()
LL1.add_begin(10)
LL1.delete_end()
LL1.print_LL()
# we will get error because reference of head will point to None
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 101>()
#      99 LL1 = LinkedList()
#     100 LL1.add_begin(10)
# --> 101 LL1.delete_end()
#     102 LL1.print_LL()
#
# Input In [12], in LinkedList.delete_end(self)
#      90 else:
#      91     n = self.head
# ---> 92     while n.ref.ref is not None:
#      93         n = n.ref
#      94     n.ref = None
#
# AttributeError: 'NoneType' object has no attribute 'ref'

# %%
# To avoid the above error we need add one more elif condition

### check when LinkedList already empty and we just want to deleted
class Node:
    def __init__(self, data):
        self.data = data
        self.ref = None

class LinkedList:
    def __init__(self):
        self.head = None  # means we have no node empty LinkedList
        
    def print_LL(self):     # Traversal operations
        if self.head is None:
            print("LinkedList is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data,"--->", end = " ")
                n = n.ref
                
    def add_begin(self,data):
        new_node = Node(data)
        new_node.ref = self.head
        self.head = new_node
        
    def add_end(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node
    def add_after(self, data, x):
        n = self.head
        while n is not None:
            if x == n.data:
                break
            n = n.ref
        if n is None:
            print("node is not present in LL")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
    def add_before(self, data, x):# we need to check whether linkedlist is empty, because empty linked
                                   # will give error so avoidthis we will use condition 
        if self.head is None:
            print("LinkedList is empty!")
            return
        
        if self.head.data == x:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
            return
        n = self.head
        while n.ref is not None:
            if n.ref.data == x:
                break
            n = n.ref
        if n.ref is None:
            print("Node is not found!")
        else:
            new_node = Node(data)
            new_node.ref = self.head
            self.head = new_node
            
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("LinkedList is not empty!")
            
    def delete_begin(self):
        if self.head is None:
            print("LinkedList is empty so we can't delete nodes!")
            
        else:
            self.head = self.head.ref
    
    def delete_end(self):
        if self.head is None:
            print("LL is empty so we can't delete nodes!")
            
        elif self.head.ref is None: # this is condition to check wether only one head is present
            self.head = None
            
        else:
            n = self.head
            while n.ref.ref is not None:
                n = n.ref
            n.ref = None
            
            
            

LL1 = LinkedList()
LL1.add_begin(10)
LL1.delete_end()
LL1.print_LL()
# Out:
# LinkedList is empty!

# %% [markdown]
# #### delete_end() :
#
# `check linked list id empty:
#       if yes : print a message
# else: check linked list contains single node
#       if yes : point head to None
# else:
#      go to second last Node and make its reference None.`
