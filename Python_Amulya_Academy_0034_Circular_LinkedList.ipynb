# %% [markdown]
# ### Circular LinkedList
#
# `Circular linked list is a linked list where all nodes are connected to form a circle. There is no NULL at the end. A circular linked list can be a singly circular linked list or doubly circular linked list.`
#
# #### Advantages of Circular Linked Lists:
#
# 1) Any node can be a starting point. We can traverse the whole list by starting from any point. We just need to stop when the first visited node is visited again.
#
# 2) Useful for implementation of queue. Unlike this implementation, we don’t need to maintain two pointers for front and rear if we use circular linked list. We can maintain a pointer to the last inserted node and front can always be obtained as next of last.
#
# 3) Circular lists are useful in applications to repeatedly go around the list. For example, when multiple applications are running on a PC, it is common for the operating system to put the running applications on a list and then to cycle through them, giving each of them a slice of time to execute, and then making them wait while the CPU is given to another application. It is convenient for the operating system to use a circular list so that when it reaches the end of the list it can cycle around to the front of the list.
#
# 4) Circular Doubly Linked Lists are used for implementation of advanced data structures like Fibonacci Heap.

# %%
# Circular Singly LinkedList.


class Node:
    
    def __init__(self, data):
        self.data = data
        self.ref = None
       #self.last = None
        

class Circular_SLL:
    
    def __init__(self):
        self.head = None  
        
    def print_LL(self):     # Traversal operations
        if self.head is None:
            print("LinkedList is empty!")
        else:
            temp = self.head
            n = self.head
            while self.head :
                print(n.data,"--->", end = " ")
                n = n.ref
                if n == temp:
                    break
                
    def insert_empty(self, data):
        
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            self.head.ref = self.head
        else:
            print("LinkedList is not empty!")
                
    def add_begin(self,data):
        
        new_node = Node(data)
        if self.head is None:   # when cLL is empty
            self.head = new_node
            self.head.ref = self.head
            
        else:
            temp = self.head  # take a temp to hold the value
            n = self.head  # now for traverse
            
            while n.ref.data !=temp.data:   # this is for traverse to last node because we need that to
                n = n.ref         # assign ref to new_node as new ref value
            
            new_node.ref = temp
            self.head = new_node   
            n.ref = new_node
            
            
        
#     def add_end(self, data):
#         new_node = Node(data)
#         if self.head is None:
#             self.head = new_node
#         else:
#             n = self.head
#             while n.ref is not None:
#                 n = n.ref
                
#             n.ref = new_node
#     def add_after(self, data, x):
#         n = self.head
#         while n is not None:
#             if x == n.data:
#                 break
#             n = n.ref
#         if n is None:
#             print("node is not present in LL")
#         else:
#             new_node = Node(data)
#             new_node.ref = n.ref
#             n.ref = new_node
#     def add_before(self, data, x):# we need to check whether linkedlist is empty, because empty linked
#                                    # will give error so avoidthis we will use condition 
#         if self.head is None:
#             print("LinkedList is empty!")
#             return
        
#         if self.head.data == x:
#             new_node = Node(data)
#             new_node.ref = self.head
#             self.head = new_node
#             return
#         n = self.head
#         while n.ref is not None:
#             if n.ref.data == x:
#                 break
#             n = n.ref
#         if n.ref is None:
#             print("Node is not found!")
#         else:
#             new_node = Node(data)
#             new_node.ref = self.head
#             self.head = new_node
            
    
            
#     def delete_begin(self):
#         if self.head is None:
#             print("LinkedList is empty so we can't delete nodes!")
            
#         else:
#             self.head = self.head.ref
    
#     def delete_end(self):
#         if self.head is None:
#             print("LL is empty so we can't delete nodes!")
#         else:
#             n = self.head
#             while n.ref.ref is not None:
#                 n = n.ref
#             n.ref = None
#     def delete_by_value(self, x):
#         if self.head is None:
#             print("can't deelete LL is empty!")
#             return # we use return so that after printig control should come out of the loop.
#         # now chaeck wether the node is first node or not 
#         if x == self.head.data:
#             self.head = self.head.ref
#             return  # if we don't want write else part then write 'return' or elif elif esle
#         n = self.head  # using this we will search the head of the previous node
#         while n.ref is not None:
#             if x == n.ref.data:
#                 break
#             n = n.ref
#         #now we are here by two condition one is when while loop satisfied and second is when
#         # nested if inside while loop satisfied and 'break' statement works.
#         if n.ref is None:
#             print("Node is not Found!")
#         else:
#             n.ref = n.ref.ref
            
            
        
csl1 = Circular_SLL()
csl1.insert_empty(20)
csl1.insert_empty(10)

csl1.add_begin(30)
csl1.add_begin(50)
csl1.add_begin(60)


csl1.print_LL()
# Out:
# LinkedList is not empty!
# 60 ---> 50 ---> 30 ---> 20 --->

# %%
# Circular Singly LinkedList.
# adding node at end 

class Node:
    
    def __init__(self, data):
        self.data = data
        self.ref = None
       #self.last = None
        

class Circular_SLL:
    
    def __init__(self):
        self.head = None  
        
    def print_LL(self):     # Traversal operations
        if self.head is None:
            print("LinkedList is empty!")
        else:
            temp = self.head
            n = self.head
            while self.head :
                print(n.data,"--->", end = " ")
                n = n.ref
                if n == temp:
                    break
                
    def insert_empty(self, data):
        
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            self.head.ref = self.head
        else:
            print("LinkedList is not empty!")
                
    def add_begin(self,data):
        
        new_node = Node(data)
        if self.head is None:   # when cLL is empty
            self.head = new_node
            self.head.ref = self.head
            
        else:
            
            temp = self.head  # take a temp to hold the value
            n = self.head  # now for traverse
            
            while n.ref.data !=temp.data:   
                # this is for traverse to last node because we need that to
                n = n.ref         # assign ref to new_node as new ref value
            
            new_node.ref = temp
            self.head = new_node   
            n.ref = new_node
            
    def add_end(self, data):
        new_node = Node(data)
        
        if self.head is None: # if CSLL is empty
            self.head = new_node
            self.head.ref = self.head
            
        else:
            temp = self.head    # took this because during traverse n.ref value will be change 
                                # but somewhere we need this value
            n = self.head
            while n.ref.data != temp.data:
                n = n.ref
            # now we are at last node and we can add node here 
            n.ref = new_node
            new_node.ref = temp
            
            
            
csll1 = Circular_SLL()
csll1.add_begin(10)
csll1.add_begin(20)
csll1.add_end(30)
csll1.print_LL()
# Out:
# 20 ---> 10 ---> 30 --->

# %%
# adding before node



class Node:
    
    def __init__(self, data):
        self.data = data
        self.ref = None
       #self.last = None
        

class Circular_SLL:
    
    def __init__(self):
        self.head = None  
        
    def print_LL(self):     # Traversal operations
        if self.head is None:
            print("LinkedList is empty!")
        else:
            temp = self.head
            n = self.head
            
            while n.ref:
                print(n.data, "--->", end = " ")
                if n.ref == temp:
                    break
                n = n.ref
            
            
            
            
            
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            new_node.ref = self.head
        else:
            print("LinkedList is not empty!")
                
    def add_begin(self,data):
        
        new_node = Node(data)
        if self.head is None:   # when cLL is empty
            self.head = new_node
            self.head.ref = self.head
            
        else:
            
            temp = self.head  # take a temp to hold the value
            n = self.head  # now for traverse
            
            while n.ref.data !=temp.data:   
                # this is for traverse to last node because we need that to
                n = n.ref         # assign ref to new_node as new ref value
            
            new_node.ref = temp
            self.head = new_node   
            n.ref = new_node
            
    def add_end(self, data):
        new_node = Node(data)
        
        if self.head is None: # if CSLL is empty
            self.head = new_node
            new_node.ref = self.head
            
        else:
            temp = self.head    # took this because during traverse n.ref value will be change 
                                # but somewhere we need this value
            n = self.head
            while n.ref != temp:
                n = n.ref
            # now we are at last node and we can add node here 
            n.ref = new_node
            new_node.ref = temp
            
            
    def add_before(self, data, x):
        
        if self.head is None:  # when node is empty
            print("CSLL is empty so can't found x in that!")
            return
               
        if self.head.data == x:   # when x is equal to the first node data 
            new_node = Node(data)
            temp = self.head
            n = self.head
            while n.ref != temp:
                n = n.ref
            
            # now we are at last node
            n.ref = new_node
            new_node.ref = temp
            self.head = new_node
            
        # now traverse through to check where is x
        else:
            temp = self.head
            n = self.head
            
            while n.ref.data != x:
                n = n.ref
                
            if n.ref.data != x:
                print("X is not found in CSLL node!")
                
            else:
                new_node = Node(data)
                new_node.ref = n.ref
                n.ref = new_node
                                
                
            
        
            
    
            
            
            
csll1 = Circular_SLL()
csll1.insert_empty(10)
csll1.add_begin(100)
csll1.add_before(20, 10)
csll1.add_end(30)
csll1.add_begin(20)
csll1.add_end(36)
csll1.print_LL()
# Out:
# 20 ---> 100 ---> 20 ---> 10 ---> 30 ---> 36 --->

# %%
# add  after node



class Node:
    
    def __init__(self, data):
        self.data = data
        self.ref = None
       #self.last = None
        

class Circular_SLL:
    
    def __init__(self):
        self.head = None  
        
    def print_LL(self):     # Traversal operations
        if self.head is None:
            print("LinkedList is empty!")
        else:
            temp = self.head
            n = self.head
            
            while n.ref:
                print(n.data, "--->", end = " ")
                if n.ref == temp:
                    break
                n = n.ref
            
            
            
            
            
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            new_node.ref = self.head
        else:
            print("LinkedList is not empty!")
                
    def add_begin(self,data):
        
        new_node = Node(data)
        if self.head is None:   # when cLL is empty
            self.head = new_node
            self.head.ref = self.head
            
        else:
            
            temp = self.head  # take a temp to hold the value
            n = self.head  # now for traverse
            
            while n.ref.data !=temp.data:   
                # this is for traverse to last node because we need that to
                n = n.ref         # assign ref to new_node as new ref value
            
            new_node.ref = temp
            self.head = new_node   
            n.ref = new_node
            
    def add_end(self, data):
        new_node = Node(data)
        
        if self.head is None: # if CSLL is empty
            self.head = new_node
            new_node.ref = self.head
            
        else:
            temp = self.head    # took this because during traverse n.ref value will be change 
                                # but somewhere we need this value
            n = self.head
            while n.ref != temp:
                n = n.ref
            # now we are at last node and we can add node here 
            n.ref = new_node
            new_node.ref = temp
            
            
    def add_before(self, data, x):
        if self.head is None:  # when node is empty
            print("CSLL is empty so can't found x in that!")
            return
        if self.head.data == x:   # when x is equal to the first node data 
            new_node = Node(data)
            temp = self.head
            n = self.head
            while n.ref != temp:
                n = n.ref
            # now we are at last node
            n.ref = new_node
            new_node.ref = temp
            self.head = new_node
        # now traverse through to check where is x
        else:
            temp = self.head
            n = self.head
            while n.ref.data != x:
                n = n.ref
            if n.ref.data != x:
                print("X is not found in CSLL node!")
            else:
                new_node = Node(data)
                new_node.ref = n.ref
                n.ref = new_node
    def add_after(self, data, x):
        if self.head is None:  # when node is empty
            print("CSLL is empty so can't found x in that!")
            return
        if self.head.data == x:   # when x is equal to the first node data 
            new_node = Node(data)
            n = self.head
            new_node.ref = n
            n.ref = new_node
        # now check where is the x
        
        else:
            temp = self.head
            n = self.head
            while n.ref.data != x:
                n = n.ref
                
            if n.ref.data != x:
                print("X is not found in CSLL node!")
                
            else:
                new_node = Node(data)
                new_node.ref = n.ref.ref
                n.ref.ref = new_node
                                
                
            
        
            
    
            
            
            
csll1 = Circular_SLL()
csll1.insert_empty(10)
# csll1.add_begin(100)
# csll1.add_before(20, 10)
csll1.add_after(50, 10)
# csll1.add_end(30)
# csll1.add_begin(20)
# csll1.add_end(36)
csll1.print_LL()
# Out:
# 10 ---> 50 --->

# %%
# Deletion operations



class Node:
    
    def __init__(self, data):
        self.data = data
        self.ref = None
       #self.last = None
        

class Circular_SLL:
    
    def __init__(self):
        self.head = None  
        
    def print_LL(self):     # Traversal operations
        if self.head is None:
            print("LinkedList is empty!")
        else:
            temp = self.head
            n = self.head
            
            while n.ref:
                print(n.data, "--->", end = " ")
                if n.ref == temp:
                    break
                n = n.ref
            
            
            
            
            
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            new_node.ref = self.head
        else:
            print("LinkedList is not empty!")
                
    def add_begin(self,data):
        
        new_node = Node(data)
        if self.head is None:   # when cLL is empty
            self.head = new_node
            self.head.ref = self.head
            
        else:
            
            temp = self.head  # take a temp to hold the value
            n = self.head  # now for traverse
            
            while n.ref.data !=temp.data:   
                # this is for traverse to last node because we need that to
                n = n.ref         # assign ref to new_node as new ref value
            
            new_node.ref = temp
            self.head = new_node   
            n.ref = new_node
            
    def add_end(self, data):
        new_node = Node(data)
        
        if self.head is None: # if CSLL is empty
            self.head = new_node
            new_node.ref = self.head
            
        else:
            temp = self.head    # took this because during traverse n.ref value will be change 
                                # but somewhere we need this value
            n = self.head
            while n.ref != temp:
                n = n.ref
            # now we are at last node and we can add node here 
            n.ref = new_node
            new_node.ref = temp
            
            
    def add_before(self, data, x):
        if self.head is None:  # when node is empty
            print("CSLL is empty so can't found x in that!")
            return
        if self.head.data == x:   # when x is equal to the first node data 
            new_node = Node(data)
            temp = self.head
            n = self.head
            while n.ref != temp:
                n = n.ref
            # now we are at last node
            n.ref = new_node
            new_node.ref = temp
            self.head = new_node
        # now traverse through to check where is x
        else:
            temp = self.head
            n = self.head
            while n.ref.data != x:
                n = n.ref
            if n.ref.data != x:
                print("X is not found in CSLL node!")
            else:
                new_node = Node(data)
                new_node.ref = n.ref
                n.ref = new_node
    def add_after(self, data, x):
        if self.head is None:  # when node is empty
            print("CSLL is empty so can't found x in that!")
            return
        if self.head.data == x:   # when x is equal to the first node data 
            new_node = Node(data)
            n = self.head
            new_node.ref = n
            n.ref = new_node
        # now check where is the x
        
        else:
            temp = self.head
            n = self.head
            while n.ref.data != x:
                n = n.ref
                
            if n.ref.data != x:
                print("X is not found in CSLL node!")
                
            else:
                new_node = Node(data)
                new_node.ref = n.ref.ref
                n.ref.ref = new_node
                                
    def delete_begin(self):
        if self.head is None:
            print("CSLL is empty so can't delete!")
        else:
            temp = self.head
            n = self.head
            self.head = n.ref
            
            while n.ref != temp:
                n = n.ref
            # now we are at last node
            n.ref = self.head
            
    def delete_end(self):
        if self.head is None:
            print("CSLL is empty so can't delete!")
        else:
            temp = self.head
            n = self.head
            while n.ref.ref != temp:
                n = n.ref
                
            # now we are at one node before last node 
            n.ref = temp
            
    def delete_by_value(self, x):
        
        if self.head is None:
            print("CSLL is empty so can't delete!")
            return
        # check if there is single node
        if self.head == self.head.ref:
            self.head = None
            print("the node got delete ")
            return
        # now we have to check whether x is the first value
        temp = self.head
        new_head_ref = self.head.ref
        if self.head.data == x:
            n = self.head
            while n.ref !=temp:
                n = n.ref
            # now we are at last node 
            self.head = new_head_ref
            n.ref = new_head_ref
            return
        # when x is not the first value means it maybe middle, last any other.    
        if self.head.data != x:
            n = self.head
            while n.ref != temp:
                if n.ref.data == x:
                    break
                n = n.ref

            if n.ref.data !=x :
                print("x is not present in node!")
                return
            else:
                n.ref = n.ref.ref
            
        
        
                 
            
        
            
    
            
            
            
csll1 = Circular_SLL()
csll1.insert_empty(10)
# csll1.add_begin(20)
# csll1.add_begin(30)
csll1.add_begin(40)

# csll1.add_before(20, 10)
#csll1.add_after(50, 10)
# csll1.add_end(30)
# csll1.add_begin(20)
# csll1.add_end(36)
#csll1.delete_begin()
#csll1.delete_end()
csll1.delete_by_value(10)
csll1.print_LL()
# Out:
# 40 --->
